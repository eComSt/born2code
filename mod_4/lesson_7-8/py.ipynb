# %%
API_KEY = "a8f6fef7a296bbce70aa16aca85698e3"
import requests
from datetime import datetime
def get_coords(city_name):
    url = 'http://api.openweathermap.org/geo/1.0/direct?'
    params = {
        "q": city_name,
        "appid": API_KEY,
        "limit": 1
    }
    responce = requests.get(url, params=params)
    data = responce.json()[0]
    return data['lat'], data['lon']

def get_daily_forecasts(city_name):
    coords = get_coords(city_name)
    url = 'https://api.openweathermap.org/data/2.5/forecast?'
    params = {
        'lat': coords[0],
        'lon': coords[1],
        'appid': API_KEY,
        'units': 'metric',
        'lang': 'ru'
    }
    response = requests.get(url, params=params)
    data = response.json()['list']
    forecasts = {}
    for elem in data:
        stamp = datetime.fromtimestamp(elem['dt'])
        date = stamp.strftime('%d.%m.%Y')
        if date not in forecasts:
            forecasts[date] = {}
        time = stamp.strftime('%H:%M')
        main = elem['main']
        description = elem['weather'][0]['description']
        wind = elem['wind']
        forecasts[date][time] = (
            f"Температура {main['temp']} °C, {description}",
            f"Ощущается как {main['feels_like']} °C",
            f"Влажность {main['humidity']} %",
            f"Ветер {wind['speed']} м/c")
    return forecasts

from pprint import pprint
pprint(get_daily_forecasts('Москва'))
# Out:
# {'01.06.2024': {'01:00': ('Температура 21.4 °C, небольшой дождь',
#                           'Ощущается как 21.45 °C',
#                           'Влажность 71 %',
#                           'Ветер 2.75 м/c'),
#                 '04:00': ('Температура 18.78 °C, небольшой дождь',
#                           'Ощущается как 18.88 °C',
#                           'Влажность 83 %',
#                           'Ветер 2.81 м/c'),
#                 '07:00': ('Температура 17.53 °C, пасмурно',
#                           'Ощущается как 17.61 °C',
#                           'Влажность 87 %',
#                           'Ветер 3.39 м/c'),
#                 '10:00': ('Температура 17.86 °C, пасмурно',
#                           'Ощущается как 17.89 °C',
#                           'Влажность 84 %',
#                           'Ветер 2.85 м/c'),
#                 '13:00': ('Температура 20.07 °C, пасмурно',
#                           'Ощущается как 19.99 °C',
#                           'Влажность 71 %',
#                           'Ветер 2.9 м/c'),
#                 '16:00': ('Температура 25.41 °C, пасмурно',
#                           'Ощущается как 25.23 °C',
#                           'Влажность 47 %',
#                           'Ветер 2.65 м/c'),
#                 '19:00': ('Температура 27.26 °C, пасмурно',
#                           'Ощущается как 27.17 °C',
#                           'Влажность 42 %',
#                           'Ветер 3.17 м/c'),
#                 '22:00': ('Температура 24.78 °C, пасмурно',
#                           'Ощущается как 24.72 °C',
#                           'Влажность 54 %',
#                           'Ветер 2.79 м/c')},
#  '02.06.2024': {'01:00': ('Температура 21.04 °C, небольшой дождь',
#                           'Ощущается как 21.21 °C',
#                           'Влажность 77 %',
#                           'Ветер 1.88 м/c'),
#                 '04:00': ('Температура 18.79 °C, дождь',
#                           'Ощущается как 19.02 °C',
#                           'Влажность 88 %',
#                           'Ветер 2.22 м/c'),
#                 '07:00': ('Температура 17.3 °C, облачно с прояснениями',
#                           'Ощущается как 17.46 °C',
#                           'Влажность 91 %',
#                           'Ветер 2.13 м/c'),
#                 '10:00': ('Температура 18.23 °C, ясно',
#                           'Ощущается как 18.33 °C',
#                           'Влажность 85 %',
#                           'Ветер 2.05 м/c'),
#                 '13:00': ('Температура 23.14 °C, ясно',
#                           'Ощущается как 23.05 °C',
#                           'Влажность 59 %',
#                           'Ветер 2.87 м/c'),
#                 '16:00': ('Температура 27.18 °C, переменная облачность',
#                           'Ощущается как 27.05 °C',
#                           'Влажность 41 %',
#                           'Ветер 3.96 м/c'),
#                 '19:00': ('Температура 26.31 °C, облачно с прояснениями',
#                           'Ощущается как 26.31 °C',
#                           'Влажность 45 %',
#                           'Ветер 2.39 м/c'),
#                 '22:00': ('Температура 26.64 °C, пасмурно',
#                           'Ощущается как 26.64 °C',
#                           'Влажность 47 %',
#                           'Ветер 4.99 м/c')},
#  '29.05.2024': {'01:00': ('Температура 23.39 °C, облачно с прояснениями',
#                           'Ощущается как 23.3 °C',
#                           'Влажность 58 %',
#                           'Ветер 2.8 м/c'),
#                 '04:00': ('Температура 20.07 °C, переменная облачность',
#                           'Ощущается как 19.99 °C',
#                           'Влажность 71 %',
#                           'Ветер 1.98 м/c'),
#                 '07:00': ('Температура 16.46 °C, переменная облачность',
#                           'Ощущается как 16.35 °C',
#                           'Влажность 84 %',
#                           'Ветер 1.5 м/c'),
#                 '10:00': ('Температура 17.15 °C, ясно',
#                           'Ощущается как 16.98 °C',
#                           'Влажность 79 %',
#                           'Ветер 1.45 м/c'),
#                 '13:00': ('Температура 22.09 °C, ясно',
#                           'Ощущается как 21.84 °C',
#                           'Влажность 57 %',
#                           'Ветер 1.54 м/c'),
#                 '16:00': ('Температура 26.09 °C, ясно',
#                           'Ощущается как 26.09 °C',
#                           'Влажность 39 %',
#                           'Ветер 1.65 м/c'),
#                 '19:00': ('Температура 25.26 °C, переменная облачность',
#                           'Ощущается как 24.91 °C',
#                           'Влажность 41 %',
#                           'Ветер 2.43 м/c'),
#                 '22:00': ('Температура 23.3 °C, пасмурно',
#                           'Ощущается как 23.1 °C',
#                           'Влажность 54 %',
#                           'Ветер 2.39 м/c')},
#  '30.05.2024': {'01:00': ('Температура 20.93 °C, облачно с прояснениями',
#                           'Ощущается как 20.78 °C',
#                           'Влажность 65 %',
#                           'Ветер 2.41 м/c'),
#                 '04:00': ('Температура 19.18 °C, пасмурно',
#                           'Ощущается как 18.98 °C',
#                           'Влажность 70 %',
#                           'Ветер 2.23 м/c'),
#                 '07:00': ('Температура 17.31 °C, пасмурно',
#                           'Ощущается как 17.21 °C',
#                           'Влажность 81 %',
#                           'Ветер 2.09 м/c'),
#                 '10:00': ('Температура 17.76 °C, облачно с прояснениями',
#                           'Ощущается как 17.6 °C',
#                           'Влажность 77 %',
#                           'Ветер 2.11 м/c'),
#                 '13:00': ('Температура 19.14 °C, облачно с прояснениями',
#                           'Ощущается как 18.86 °C',
#                           'Влажность 67 %',
#                           'Ветер 3.25 м/c'),
#                 '16:00': ('Температура 21.29 °C, пасмурно',
#                           'Ощущается как 20.86 °C',
#                           'Влажность 53 %',
#                           'Ветер 2.27 м/c'),
#                 '19:00': ('Температура 25.17 °C, пасмурно',
#                           'Ощущается как 24.58 °C',
#                           'Влажность 32 %',
#                           'Ветер 3.29 м/c'),
#                 '22:00': ('Температура 23.82 °C, пасмурно',
#                           'Ощущается как 23.35 °C',
#                           'Влажность 42 %',
#                           'Ветер 4.52 м/c')},
#  '31.05.2024': {'01:00': ('Температура 19.8 °C, пасмурно',
#                           'Ощущается как 19.51 °C',
#                           'Влажность 64 %',
#                           'Ветер 2.84 м/c'),
#                 '04:00': ('Температура 18.93 °C, пасмурно',
#                           'Ощущается как 18.55 °C',
#                           'Влажность 64 %',
#                           'Ветер 1.76 м/c'),
#                 '07:00': ('Температура 17.42 °C, пасмурно',
#                           'Ощущается как 17.05 °C',
#                           'Влажность 70 %',
#                           'Ветер 1.38 м/c'),
#                 '10:00': ('Температура 17.29 °C, облачно с прояснениями',
#                           'Ощущается как 16.9 °C',
#                           'Влажность 70 %',
#                           'Ветер 2.35 м/c'),
#                 '13:00': ('Температура 21.37 °C, облачно с прояснениями',
#                           'Ощущается как 21 °C',
#                           'Влажность 55 %',
#                           'Ветер 3.61 м/c'),
#                 '16:00': ('Температура 24.36 °C, пасмурно',
#                           'Ощущается как 24.1 °C',
#                           'Влажность 48 %',
#                           'Ветер 5.24 м/c'),
#                 '19:00': ('Температура 25.38 °C, пасмурно',
#                           'Ощущается как 25.25 °C',
#                           'Влажность 49 %',
#                           'Ветер 5.03 м/c'),
#                 '22:00': ('Температура 24.94 °C, облачно с прояснениями',
#                           'Ощущается как 24.87 °C',
#                           'Влажность 53 %',
#                           'Ветер 5.14 м/c')}}
